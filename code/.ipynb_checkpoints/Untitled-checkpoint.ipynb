# %%
import pandas as pd
import numpy as np
import nltk as nltk
import os
from datetime import datetime as dt

pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
#Read in data
os.chdir('..')
cwd=os.getcwd()
os.chdir(cwd+'/data')

data_df = pd.read_csv('parsed_data.csv')
# data_df.head()

# %%
new_names = {}
for item in data_df.columns:
    new_names[item]=item.lower()

data_df.rename(columns=new_names,inplace=True)

# %%
print(data_df['creationdate'][0])
print(dt.strptime(data_df['creationdate'][0][:-4], '%m/%d/%y %I:%M:%S %p'))
# Out:
# 06/10/15 02:59:53 AM PDT
# 2015-06-10 02:59:53

# %%
def convert_time(item):
    if type(item)==str:
        return dt.strptime(item[:-4],'%m/%d/%y %I:%M:%S %p')
    else:
        return np.nan

# %%
print(convert_time(data_df['creationdate'][0]))
# Out:
# 2015-06-10 02:59:53

# %%
type(convert_time(data_df['creationdate'][0]))
# Out:
# datetime.datetime

# %%
type(data_df['creationdate'][0])
# Out:
# str

# %%
fix_these = {'02/18/1605:12:00 AM PST':'02/18/16 05:12:00 AM PST',
             '03/22/1607:17:38 AM PDT':'03/22/16 07:17:38 AM PDT', 
             '04/13/1607:31:13 AM PDT':'04/13/16 07:31:13 AM PDT', 
             '10/20/16 07:51:40AM PDT':'10/20/16 07:51:40 AM PDT', 
             '11/03/1608:21:10 AM PST':'11/03/16 08:21:10 AM PST', 
             '11/10/1607:17:06 AM PST':'11/10/16 07:17:06 AM PST', 
             '11/01/16 03:03:08 AM P':'11/01/16 03:03:08 AM PST', 
             '11/01/16 08:03:20 AM P':'11/01/16 08:03:20 AM PST', 
             '11/01/16 08:04:40 AM PST':'11/01/16 08:04:40 AM PST', 
             '12/07/1611:37:56 PM PST':'12/07/16 11:37:56 PM PST', 
             '12/08/1606:22:13 AM PST':'12/08/16 06:22:13 AM PST', 
             '12/27/1611:32:51 PM PST':'12/27/16 11:32:51 PM PST', 
             '05/16/1706:17:51 AM PDT':'05/16/17 06:17:51 AM PDT', 
             '05/17/17 04:21:04AM PDT':'05/17/17 04:21:04 AM PDT', 
             '02/07/1707:18:42 AM PST':'02/07/17 07:18:42 AM PST', 
             '02/06/1707:17:41 AM PST':'02/06/17 07:17:41 AM PST', 
             '03/14/17 07:01:00AM PDT':'03/14/17 07:01:00 AM PDT'}

# %%
fix_these['02/18/1605:12:00 AM PST']
# Out:
# '02/18/16 05:12:00 AM PST'

# %%
for item in data_df['creationdate']:
    if item in fix_these:
        data_df['creationdate'] = fix_these[item]
    else:
        data_df['creationdate'] = data_df['creationdate']

# %%
data_df['date_time'] = data_df['creationdate'].map(convert_time)
# data_df.head()

# %%
# Determine amount of missing data in each columns
# If more than 50% of a columns entires are NaN, then we drop that column
for item in data_df.columns:
    nulls = data_df[item].isnull().sum()
    missing = round(nulls*1.0/data_df.shape[0]*100,2)
    if missing > 10:
        print("{} has {} null values ({}%)".format(item,nulls,missing))
    if missing > 2/3*100:
        data_df = data_df.drop(item, axis=1)
# Out:
# enddate has 1230 null values (34.98%)
# behaviors has 3171 null values (90.19%)
# peoplewhomatch has 3090 null values (87.88%)
# interests has 797 null values (22.67%)
# language has 1909 null values (54.29%)
# friendsofconnections has 3106 null values (88.34%)
# excludedconnections has 2567 null values (73.01%)
# gender has 3367 null values (95.76%)
# generation has 3512 null values (99.89%)
# politics has 3458 null values (98.35%)
# customaudience has 3486 null values (99.15%)
# adspend has 1042 null values (29.64%)
# adspendcurrency has 978 null values (27.82%)

# %%
data_df.shape
# Out:
# (3516, 18)

# %%
def text_cleaner(text):
    # print(type(text))
    new_words = []
    stop_words = nltk.corpus.stopwords.words('english')
    if type(text) == str:
        # print('Cleaning...')
        for item in nltk.word_tokenize(text):
            if item not in stop_words and item.isalnum():
                new_words.append(item)
        return new_words
    else:
        # print('Not a string')
        return np.nan

# %%
data_df['clean_text'] = data_df['adtext'].map(text_cleaner)
data_df['clean_text'].head()
# Out:
# 0                     [Join, us, care, Black, matters]
# 1    [NOT, EVERY, BOY, WANTS, TO, BE, A, SOLDIER, A...
# 2    [People, tolerate, two, homosexuals, see, leav...
# 3                                                   []
# 4    [California, knows, party, California, knows, ...
# Name: clean_text, dtype: object

# %%
data_df.head()
# Out:
#    adid                                             adtext  clicks  \
# 0   374            Join us because we care. Black matters.     0.0
# 1   655  NOT EVERY BOY WANTS TO BE A SOLDIER. A beautif...    35.0
# 2   664  "People can tolerate two homosexuals they see ...    26.0
# 3    79                      ?????? ??? ????? ? ??????????     0.0
# 4   325  California... knows how to party California......     4.0
#
#    impressions       age              creationdate                   enddate  \
# 0        137.0  18 - 65+  03/14/17 07:01:00 AM PDT                       NaN
# 1        452.0  18 - 65+  03/14/17 07:01:00 AM PDT  06/24/15 07:04:00 AM PDT
# 2        374.0  18 - 65+  03/14/17 07:01:00 AM PDT  06/24/15 07:02:39 AM PDT
# 3         31.0  18 - 65+  03/14/17 07:01:00 AM PDT  06/11/15 03:48:00 AM PDT
# 4        326.0  18 - 65+  03/14/17 07:01:00 AM PDT  06/11/15 07:34:51 AM PDT
#
#                                          landingpage  \
# ...

# %%
data_df.columns
# Out:
# Index(['adid', 'adtext', 'clicks', 'impressions', 'age', 'creationdate',
#        'enddate', 'landingpage', 'location', 'placements', 'interests',
#        'language', 'adspend', 'adspendcurrency', 'sourcefile', 'sourcezip',
#        'pages', 'date_time', 'clean_text'],
#       dtype='object')

# %%
print(data_df.dtypes)
# Out:
# adid                        int64
# adtext                     object
# clicks                    float64
# impressions               float64
# age                        object
# creationdate               object
# enddate                    object
# landingpage                object
# location                   object
# placements                 object
# interests                  object
# language                   object
# adspend                   float64
# adspendcurrency            object
# sourcefile                 object
# sourcezip                  object
# pages                       int64
# date_time          datetime64[ns]
# clean_text                 object
# dtype: object

# %%
for item in data_df.columns:
    if data_df[item].dtype == 'object':
        print(item)
        print(len(data_df[item].unique()))
        print('----- \n')
# Out:
# adtext
# 2407
# -----
#
# age
# 64
# -----
#
# creationdate
# 1
# -----
#
# enddate
# 1935
# -----
#
# landingpage
# 487
# -----
#
# location
# 154
# -----
#
# placements
# 27
# -----
#
# interests
# 581
# -----
#
# language
# 6
# -----
#
# adspendcurrency
# 3
# -----
#
# sourcefile
# 3516
# -----
#
# sourcezip
# 11
# -----
#
# clean_text
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-1a583f72893c> in <module>()
#       2     if data_df[item].dtype == 'object':
#       3         print(item)
# ----> 4         print(len(data_df[item].unique()))
#       5         print('----- \n')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in unique(self)
#    1281     @Appender(base._shared_docs['unique'] % _shared_doc_kwargs)
#    1282     def unique(self):
# -> 1283         result = super(Series, self).unique()
#    1284
# ...

# %%
data_df['age'].unique()
# Out:
# array(['18 - 65+', '18 - 55', '18 - 54', '16 - 65+', '18 - 51', '20 - 65+',
#        '16 - 40', '14 - 65+', '15 - 65+', '18 - 50', '25 - 65+',
#        '13 - 65+', '18 - 59', '14 - 36', '13 - 35', '13 - 40', '18 - 45',
#        '13 - 50', '13 - 45', '13 - 42', '18 - 48', '13 - 27', '18 - 60',
#        '16 - 54', '20 - 35', '13 - 44', '14 - 50', '16 - 45', '35 - 65+',
#        '19 - 30', '18 - 53', '14 - 54', '17 - 61', '16 - 60', '18- 51',
#        '15 - 54', '21 - 65+', '16 - 53', '13 - 55', '13 - 30', '15 - 25',
#        '14 - 17', '15 - 30', '14 - 40', '13 - 60', '18 - 43', '18 - 40',
#        '18 65+', '18 - 61', '24 - 45', '45 - 64', '17 - 65+', '16 - 55',
#        '15 - 26', '45 - 65+', '16 - 50', '18 - 24', '24 - 65+', '30 - 65+',
#        '40 - 65+', '16 - 25', '15 - 40', '18 - 39', '20 - 45'], dtype=object)

# %%
data_df['age'].value_counts()
# Out:
# 18 - 65+    2364
# 16 - 65+     356
# 18 - 54      124
# 18 - 45       71
# 18 - 51       48
# 14 - 40       45
# 15 - 25       45
# 13 - 65+      36
# 18 - 50       31
# 21 - 65+      30
# 35 - 65+      28
# 14 - 65+      28
# 13 - 30       25
# 18 - 59       20
# 25 - 65+      17
# 19 - 30       16
# 16 - 45       16
# 15 - 30       14
# 13 - 45       14
# 13 - 40       14
# 16 - 53       12
# 14 - 54       10
# 16 - 25        9
# 13 - 35        9
# 14 - 17        8
# 17 - 65+       8
# 45 - 64        8
# 18 - 60        7
# 24 - 45        7
# 15 - 40        6
# 18 65+         6
# 16 - 40        6
# 15 - 54        5
# 30 - 65+       4
# 13 - 44        4
# 45 - 65+       4
# 18 - 39        4
# 16 - 55        4
# 18 - 48        4
# 13 - 50        4
# 20 - 45        4
# 15 - 65+       3
# 18 - 55        3
# 20 - 65+       3
# 24 - 65+       3
# 13 - 60        3
# 16 - 60        3
# 18 - 61        3
# 18 - 24        2
# 18- 51         2
# 15 - 26        2
# 16 - 54        2
# ...

# %%
data_df['age'][0]
# Out:
# '18 - 65+'

# %%
def min_age(cell):
    return cell[0:2]

# %%
def max_age(cell):
    if cell[-1] == '+':
        return int(cell[-3:-1])
    else:
        return int(cell[-2:])

# %%
data_df['age_lower'] = pd.to_numeric(data_df['age'].map(min_age))
data_df['age_upper'] = pd.to_numeric(data_df['age'].map(max_age))

# %%
data_df[['age','age_lower','age_upper']].dtypes
# Out:
# age          object
# age_lower     int64
# age_upper     int64
# dtype: object

# %%
370895.0/(370895+8743876)*100
# Out:
# 4.069164217071389

# %%
data_df['enddate']
# Out:
# 0                            NaN
# 1       06/24/15 07:04:00 AM PDT
# 2       06/24/15 07:02:39 AM PDT
# 3       06/11/15 03:48:00 AM PDT
# 4       06/11/15 07:34:51 AM PDT
# 5                            NaN
# 6       06/12/15 06:51:29 AM PDT
# 7       06/12/15 07:03:57 AM PDT
# 8       06/16/15 07:21:33 AM PDT
# 9       06/16/15 07:21:59 AM PDT
# 10      06/16/15 07:21:47 AM PDT
# 11      06/16/15 07:22:20 AM PDT
# 12      06/17/15 07:36:56 AM PDT
# 13      06/17/15 07:37:13 AM PDT
# 14      06/17/15 08:20:30 AM PDT
# 15      06/18/15 07:41:33 AM PDT
# 16      06/18/15 07:41:06 AM PDT
# 17      06/18/15 07:41:45 AM PDT
# 18      06/18/15 07:42:01 AM PDT
# 19      06/18/15 07:45:32 AM PDT
# 20      06/19/15 04:36:59 AM PDT
# 21      06/19/15 02:50:24 AM PDT
# 22      06/19/15 07:21:41 AM PDT
# 23                           NaN
# 24      06/24/15 07:41:20 AM PDT
# 25      06/24/15 07:41:58 AM PDT
# 26      06/24/15 07:42:11 AM PDT
# 27      06/24/15 07:42:34 AM PDT
# ...

# %%
end_date_errors = {'07/11/1505:36:03AM PDT':'07/11/15 05:36:03 AM PDT',
                   '07/11/1507:00:00AM PDT':'07/11/15 07:00:00 AM PDT',
                   '11/10/1607:21:10 AM PST':'11/10/16 07:21:10 AM PST',
                   '12/08/1611:37:56 PM PST':'12/08/16 11:37:56 PM PST',
                   '12/09/1606:22:13 AM PST':'12/09/16 06:22:13 AM PST',
                   '01/27/17 01:29:39AM PST':'01/27/17 01:29:39 AM PST',
                   '03/30/17 07:31:03AM PDT':'03/30/17 07:31:03 AM PDT'}

# %%
for item in data_df['enddate']:
    if type(item) != str:
        continue
    elif len(item) != len(data_df['enddate'][1]):
        print(item)
# Out:
# 07/11/1505:36:03AM PDT
# 07/11/1507:00:00AM PDT
# 11/10/1607:21:10 AM PST
# 12/08/1611:37:56 PM PST
# 12/09/1606:22:13 AM PST
# 01/27/17 01:29:39AM PST
# 03/30/17 07:31:03AM PDT

# %%
data_df['creation_date'] = data_df['creationdate'].map(convert_time)
data_df['end_date'] = data_df['enddate'].map(convert_time)
data_df.drop('creationdate',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-deee8b6cf55f> in <module>()
# ----> 1 len(np.nan)
#
# TypeError: object of type 'float' has no len()
